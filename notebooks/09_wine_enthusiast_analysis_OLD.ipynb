# %% [markdown]
# # Analysis on Wine Enthusiast Reviews

# %%
import numpy as np
import pandas as pd

import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer

from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.manifold import MDS

from gensim import corpora, models, similarities 


import re
import os
import codecs
import dill

import multiprocess as multiprocessing

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import mpld3

sns.set_context('notebook')
sns.set_palette('dark')
sns.set_style('white')

# %%
data = pd.read_pickle('../pkl/07_wine_enthusiast_data_cleaned.pkl')

# %%
data.shape
# Out:
# (131824, 15)

# %%
# shorten to 10,000 randomly selected reviews to speed up initial analysis
data = data.loc[np.random.choice(data.index, 2000)]
data.shape
# Out:
# (2000, 15)

# %%
data.head(2)
# Out:
#         alcohol                                        appellation  \
# 174834      NaN             Tierra Manchuela, Central Spain, Spain
# 155689     12.0  The Hamptons, Long Island, Long Island, New Yo...
#
#         bottle_size category date_published designation  \
# 174834          NaN      Red     2004-03-01   Protocolo
# 155689          NaN    White     2006-08-01     Reserve
#
#                         importer list_url_no  price  rating  \
# 174834  Jorge Ordoñez Selections        5841    6.0    86.0
# 155689                       NaN        5202   20.0    84.0
#
#                                                    review  \
# 174834  Subdued and earthy, with cool, compact red-fru...
# 155689  Still young-looking, with a touch of green to ...
#
#                                                     title  \
# 174834  Dominio de Eguren 2001 Protocolo Tempranillo (...
# 155689  Wölffer 2002 Reserve Chardonnay (The Hamptons,...
#
#                                                       url      variety  \
# 174834  http://www.winemag.com/buying-guide/dominio-eg...  Tempranillo
# 155689  http://www.winemag.com/buying-guide/wolffer-20...   Chardonnay
#
#                    winery
# 174834  Dominio de Eguren
# 155689           WÃ¶lffer

# %% [markdown]
# ## Stemming and tokenizing

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(['s',"'s"])
stopwords.extend([x.lower() for x in data.variety.unique()])
stemmer = SnowballStemmer('english')

# %%
wordnet_lemmatizer = WordNetLemmatizer()

def tokenize_with_lemmatizing(text):
    text = text.lower()
    # Tokenize sentences and words
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    
    # Remove non-alphanumeric terms, convert to lower case
    tokens = [word for word in tokens if re.search('[a-zA-Z]', word)]
    
    # Remove stopwords
    tokens = [word for word in tokens if word not in stopwords]
    
    # Lemmatize the words
    tokens = [wordnet_lemmatizer.lemmatize(word) for word in tokens]
    
    return tokens

def tokenize_with_stemming(text):
    text = text.lower()
    
    # Tokenize sentences and words
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    
    # Remove non-alphanumeric terms, convert to lower case
    tokens = [word for word in tokens if re.search('[a-zA-Z]', word)]
    
    # Remove stopwords
    tokens = [word for word in tokens if word not in stopwords]
    
    # Stemm the words
    tokens = [stemmer.stem(word) for word in tokens]
    
    return tokens
    
def tokenize(text):
    text = text.lower()
    
    # Tokenize sentences and words
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    
    # Remove non-alphanumeric terms, convert to lower case
    tokens = [word for word in tokens if re.search('[a-zA-Z]', word)]
    
    # Remove stopwords
    tokens = [word for word in tokens if word not in stopwords]
    
    return tokens

# %%
data['word_token'] = data.review.apply(tokenize)
data['word_stem'] = data.review.apply(tokenize_with_stemming)
data['word_lemm'] = data.review.apply(tokenize_with_lemmatizing)

# %%
data[['word_token','word_stem']].head(2)
# Out:
#                                                word_token  \
# 174834  [subdued, earthy, cool, compact, red-fruit, ar...
# 155689  [still, young-looking, touch, green, pale, yel...
#
#                                                 word_stem
# 174834  [subdu, earthi, cool, compact, red-fruit, arom...
# 155689  [still, young-look, touch, green, pale, yellow...

# %%
stem_df = pd.DataFrame({'stem':sum(data.word_stem.tolist(),[]), 
                        'lemm':sum(data.word_lemm.tolist(),[]), 
                        'word':sum(data.word_token.tolist(),[])}).drop_duplicates().reset_index(drop=True)

# %%
stem_df.shape
# Out:
# (6205, 3)

# %%
stem_df.head()
# Out:
#         lemm       stem       word
# 0    subdued      subdu    subdued
# 1     earthy     earthi     earthy
# 2       cool       cool       cool
# 3    compact    compact    compact
# 4  red-fruit  red-fruit  red-fruit

# %% [markdown]
# ## Tf-idf
#
# # TODO: select optimized TF-IDF parameters

# %%
# TF-IDF for words, stemmed words, lemmatized words with a range of min/max values
tfidf_list = list()
corpus = data.review.tolist()

for max_df in [0.8, 0.85, 0.9, 0.95]:
    for min_df in [0.2, 0.15, 0.1, 0.05]:
        for nam,tokenizer in zip(['word','stem','lemm'], 
                                 [tokenize, tokenize_with_stemming, tokenize_with_lemmatizing]):
            
                label = 'tfidf_{}_{}_{}'.format(nam, min_df, max_df)
                
                tfidf = TfidfVectorizer(max_df = max_df, max_features=200000,
                                       min_df=min_df, stop_words='english', use_idf=True,
                                       tokenizer=tokenizer, ngram_range=(1,3))
                
                tfidf_matrix = tfidf.fit_transform(corpus)
                tfidf_list.append(pd.Series({'label':label, 'tfidf':tfidf, 'tfidf_matrix':tfidf_matrix}))

# %%
tfidf_df = pd.concat(tfidf_list, axis=1).T

# %%
tfidf_df['feature_names'] = tfidf_df.tfidf.apply(lambda x: x.get_feature_names())

# %%
tfidf_df['dist'] = tfidf_df.tfidf_matrix.apply(lambda x: 1 - cosine_similarity(x))

# %% [markdown]
# ## K-means clustering
#
# # TODO: select optimized K-means clusters

# %%
# Run kmeans clustering on entire range of tfidf matrices
kmeans_list = list()

# for num_clusters in range(3,16):
for num_clusters in range(3,11):
    
    for idx,dat in tfidf_df.iterrows():
        km = KMeans(n_clusters=num_clusters, n_jobs=-1)
        km.fit(dat.tfidf_matrix)
        kmeans_list.append(pd.Series({'num_clusters':num_clusters, 
                                      'label':dat['label']+'_{}'.format(num_clusters), 
                                      'km':km}))
                           
kmeans_df = pd.concat(kmeans_list, axis=1).T
                           
with open('../pkl/08_wine_enthusiast_kmeans_models.pkl','wb') as fh:
    dill.dump(kmeans_df, fh)
    
with open('../pkl/08_wine_enthusiast_kmeans_models.pkl','rb') as fh:
    kmeans_df = dill.load(fh)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8add445678d8> in <module>()
#      15
#      16 with open('../pkl/08_wine_enthusiast_kmeans_models.pkl','w') as fh:
# ---> 17     dill.dump(kmeans_df, fh)
#      18
#      19 with open('../pkl/08_wine_enthusiast_kmeans_models.pkl','r') as fh:
#
# NameError: name 'dill' is not defined

# %%
# Create a matrix of cluster values

cluster_df = pd.DataFrame([], index=data.index)

for idx,dat in kmeans_df.iterrows():
    km = dat.km
    label = dat.label
    num_clusters = dat.num_clusters
    cluster = km.labels_
    
    if (num_clusters >= 3)&(cluster.max()>0):
        cluster_df[label] = cluster
        
cluster_df[['category','variety','price','rating','title','appellation']] = data[['category','variety','price','rating','title','appellation']]

# %%
# Create a table of category counts per cluster
total_list = list()

tfidf_cols = pd.Series([x for x in cluster_df.columns if 'tfidf' in x],
                       index=pd.Index([int(re.search(r"""_([0-9]+)$""", x).group(1)) 
                       for x in cluster_df.columns if re.search(r"""_([0-9]+)$""", x)]))

std_cols = ['category', 'variety', 'price', 'rating', 'title', 'appellation']

# fig, axList = plt.subplots(nrows=8,ncols=6)
# fig.set_size_inches(16,20)
# color_list = sns.color_palette()
        
for nclusters in range(3,11):
    print(nclusters)
    col_list = tfidf_cols.loc[tfidf_cols.index == nclusters].values.tolist()

    sum_list = list()
    for col in col_list:

        # Create a table of number of categories in each cluster
        table = (pd.concat([data[['category']], cluster_df[[col]]], axis=1)
                 .groupby([col,'category'])
                 .size()
                 .to_frame()
                 .reset_index()
                 .rename(columns={0:'count',col:'cluster'}))
        table['col'] = col
        table = table.set_index(['col','cluster','category'])
        table_norm = table.div(table.groupby(level=[0,1]).transform(sum))
        table_norm = table_norm.rename(columns={'count':'norm'})

        # Calcualate the normalized difference between red and white wines
        table_diff = (table_norm
                 .reset_index(level=-1)
                 .groupby(level=1, group_keys=False)
                 .apply(lambda x: np.abs(x.loc[x.category=='Red','norm'] 
                                    - x.loc[x.category=='White','norm'])))

        # collect the tables
        df = pd.concat([table, table_norm], axis=1)
        sum_list.append(df)

#     # Save the figure
#     for ax,df in zip(axList.flatten(),sum_list):
#         ax.cla()

#         sns.barplot(x='cluster',
#                     y='norm',
#                     hue='category',
#                     data=df.reset_index(level=0,drop=True).reset_index(),
#                     palette={'Red':color_list[2],'Rose':'pink','White':'white'}, ax=ax)
#         ax.set(title=df.index.get_level_values(0).unique()[0],xlabel='',ylabel='')
#         ax.set_xticklabels([])
#         ax.legend().set_visible(False)

#     plt.tight_layout()
#     fig.savefig('clusters_{}.pdf'.format(nclusters))

    total_list.extend(sum_list)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10

# %%
km = kmeans_df.km.iloc[0]

# order_centroids
# order_centroids.shape,  len(terms)

for idx,dat in kmeans_df.iterrows():
    nclusters = dat.num_clusters
    km = dat.km
    label = dat.label
    order_centroids = km.cluster_centers_.argsort()[:, ::-1] 
    print("TF-IDF %s:" % label)
    
    for ind in range(nclusters):
        label_short = re.sub('_{}'.format(nclusters),'',label)
        terms = tfidf_df.loc[tfidf_df.label==label_short].feature_names.values
        for col in order_centroids[ind]:
            print(terms[0][col],end=',')
            
        print()
    print()
        #print(' %s' % stem_df.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
#         print(i, ind)#, terms[ind])
# Out:
# TF-IDF tfidf_word_0.2_0.8_3:
# flavors,finish,palate,aromas,cherry,tannins,acidity,wine,fruit,
# fruit,wine,flavors,finish,aromas,cherry,tannins,acidity,palate,
# wine,acidity,flavors,tannins,cherry,finish,aromas,palate,fruit,
#
# TF-IDF tfidf_stem_0.2_0.8_3:
# finish,palat,aroma,flavor,cherri,acid,tannin,fruit,wine,
# fruit,wine,flavor,acid,tannin,finish,cherri,aroma,palat,
# wine,flavor,cherri,acid,tannin,finish,aroma,palat,fruit,
#
# TF-IDF tfidf_lemm_0.2_0.8_3:
# flavor,finish,aroma,palate,fruit,wine,acidity,cherry,tannin,
# cherry,tannin,flavor,wine,finish,fruit,aroma,acidity,palate,
# wine,fruit,acidity,flavor,tannin,finish,cherry,aroma,palate,
#
# TF-IDF tfidf_word_0.15_0.8_3:
# flavors,finish,palate,aromas,cherry,tannins,black,oak,acidity,ripe,wine,fruit,
# wine,acidity,flavors,ripe,tannins,cherry,oak,finish,black,aromas,palate,fruit,
# fruit,wine,flavors,finish,oak,aromas,cherry,tannins,black,ripe,acidity,palate,
#
# TF-IDF tfidf_stem_0.15_0.8_3:
# wine,fruit,acid,flavor,ripe,rich,drink,tannin,dri,spice,oak,finish,black,aroma,note,palat,cherri,
# finish,flavor,aroma,palat,note,fruit,wine,oak,acid,dri,spice,drink,ripe,rich,tannin,cherri,black,
# cherri,black,tannin,flavor,wine,dri,spice,drink,oak,finish,acid,fruit,note,rich,aroma,ripe,palat,
#
# TF-IDF tfidf_lemm_0.15_0.8_3:
# cherry,tannin,black,flavor,wine,spice,oak,drink,ripe,finish,fruit,note,aroma,palate,acidity,
# finish,flavor,aroma,palate,note,fruit,wine,oak,acidity,spice,ripe,drink,cherry,tannin,black,
# wine,fruit,acidity,flavor,ripe,drink,spice,oak,tannin,finish,cherry,note,aroma,black,palate,
#
# TF-IDF tfidf_word_0.1_0.8_3:
# palate,aromas,finish,nose,flavors,notes,cherry,wine,black,spice,fresh,tannins,drink,oak,acidity,ripe,good,sweet,red,soft,fruit,dry,rich,
# fruit,wine,flavors,finish,tannins,oak,black,cherry,aromas,ripe,red,acidity,drink,spice,notes,good,rich,fresh,dry,soft,palate,sweet,nose,
# wine,flavors,acidity,dry,tannins,ripe,rich,sweet,cherry,oak,drink,black,soft,good,red,spice,fresh,finish,notes,aromas,palate,fruit,nose,
#
# TF-IDF tfidf_stem_0.1_0.8_3:
# wine,fruit,acid,flavor,ripe,rich,fresh,drink,spice,dri,oak,good,balanc,sweet,tannin,red,finish,soft,berri,aroma,cherri,note,black,plum,blackberri,palat,nose,
# cherri,black,tannin,flavor,blackberri,dri,wine,soft,spice,drink,oak,fruit,finish,plum,rich,ripe,sweet,acid,red,balanc,note,aroma,good,palat,nose,berri,fresh,
# finish,aroma,palat,flavor,note,nose,fruit,berri,sweet,wine,acid,oak,dri,fresh,plum,good,spice,drink,red,cherri,ripe,rich,balanc,soft,tannin,blackberri,black,
#
# TF-IDF tfidf_lemm_0.1_0.8_3:
# wine,fruit,acidity,flavor,ripe,drink,fresh,finish,tannin,rich,red,spice,oak,dry,good,black,note,berry,cherry,aroma,soft,plum,blackberry,sweet,palate,nose,
# flavor,cherry,tannin,black,dry,wine,sweet,blackberry,oak,soft,spice,rich,good,finish,drink,ripe,acidity,fruit,red,plum,aroma,note,berry,palate,nose,fresh,
# aroma,palate,finish,note,flavor,nose,berry,fruit,wine,plum,cherry,fresh,oak,drink,acidity,spice,good,red,ripe,tannin,sweet,black,dry,soft,blackberry,rich,
#
# TF-IDF tfidf_word_0.05_0.8_3:
# wine,acidity,flavors,ripe,fruit,sweet,fruits,crisp,rich,drink,dry,fresh,good,texture,red,oak,fruity,soft,citrus,vanilla,like,style,spice,cherries,light,structure,clean,juicy,tannins,balanced,pinot,bright,apple,shows,finish,years,white,tart,peach,fine,berry,raspberry,green,spicy,touch,notes,cherry,tannic,firm,mouth,offers,aromas,palate,bit,pepper,dark,plum,long,black,chocolate,blackberry,nose,
# black,tannins,cherry,flavors,wine,fruit,blackberry,oak,dark,dry,chocolate,soft,finish,spice,rich,years,aromas,plum,ripe,shows,drink,red,firm,pepper,palate,tannic,good,fine,raspberry,sweet,cherries,notes,structure,vanilla,pinot,nose,mouth,spicy,offers,like,balanced,long,acidity,berry,juicy,bit,texture,touch,fresh,crisp,bright,fruits,fruity,green,style,tart,clean,light,white,citrus,peach,apple,
# finish,aromas,palate,flavors,nose,notes,fruit,apple,berry,bit,wine,green,peach,citrus,long,oak,white,mouth,tart,spice,light,plum,vanilla,fresh,bright,acidity,drink,shows,offers,good,sweet,raspberry,touch,cherry,clean,red,ripe,crisp,like,pinot,spicy,pepper,style,dry,rich,soft,chocolate,blackberry,tannins,texture,juicy,tannic,balanced,dark,fruits,firm,fruity,cherries,fine,structure,years,black,
#
# TF-IDF tfidf_stem_0.05_0.8_3:
# wine,fruit,acid,flavor,ripe,rich,drink,fresh,age,crisp,spice,tannin,structur,red,textur,dri,oak,balanc,fruiti,year,light,miner,juici,style,sweet,good,berri,soft,bright,make,citrus,firm,finish,like,tast,toast,vineyard,fine,spici,aroma,peach,complex,touch,vanilla,white,appl,eleg,note,tannic,dark,cherri,clean,pear,pinot,black,mouth,hint,green,plum,smooth,tart,offer,raspberri,chocol,nice,feel,palat,bit,long,currant,blackberri,pepper,nose,herb,black cherri,
# finish,palat,aroma,flavor,note,nose,appl,fruit,berri,wine,acid,peach,green,sweet,citrus,oak,bit,pear,good,tart,dri,vanilla,hint,white,mouth,fresh,light,offer,miner,long,spice,plum,herb,touch,bright,feel,clean,drink,ripe,crisp,raspberri,rich,cherri,soft,like,red,toast,pepper,style,balanc,nice,pinot,textur,chocol,tast,spici,eleg,complex,make,tannin,dark,vineyard,blackberri,smooth,juici,tannic,fruiti,firm,structur,age,fine,year,black,currant,black cherri,
# cherri,black,tannin,flavor,blackberri,wine,dri,black cherri,currant,soft,spice,oak,raspberri,plum,finish,drink,chocol,fruit,dark,sweet,rich,ripe,aroma,pinot,pepper,acid,red,year,good,note,complex,balanc,fine,palat,offer,herb,tannic,smooth,nice,firm,structur,like,vanilla,age,vineyard,eleg,spici,textur,tast,mouth,bit,feel,hint,long,nose,make,berri,fresh,fruiti,touch,crisp,juici,toast,clean,tart,light,bright,style,green,white,miner,citrus,pear,peach,appl,
#
# TF-IDF tfidf_lemm_0.05_0.8_3:
# finish,aroma,flavor,palate,note,nose,apple,fruit,peach,wine,green,berry,vanilla,oak,bit,pear,hint,sweet,citrus,good,tart,long,white,mouth,fresh,herb,touch,light,acidity,offer,plum,feel,drink,bright,spice,ripe,dry,like,raspberry,clean,crisp,style,cherry,soft,pepper,rich,pinot,red,make,chocolate,spicy,balanced,tannin,vineyard,blackberry,texture,balance,tannic,juicy,dark,fruity,year,firm,fine,structure,black,currant,black cherry,
# cherry,tannin,black,flavor,blackberry,wine,oak,currant,dry,black cherry,plum,fruit,chocolate,dark,spice,finish,soft,aroma,drink,year,raspberry,red,note,rich,ripe,pinot,pepper,sweet,good,palate,herb,firm,fine,tannic,berry,vanilla,offer,structure,vineyard,like,acidity,balance,bit,spicy,nose,mouth,feel,hint,texture,balanced,long,make,juicy,fresh,touch,fruity,crisp,bright,tart,clean,style,white,green,light,citrus,pear,peach,apple,
# wine,fruit,acidity,flavor,ripe,crisp,rich,drink,spice,red,dry,fresh,texture,tannin,fruity,oak,berry,light,sweet,year,good,soft,structure,style,citrus,juicy,bright,finish,raspberry,like,clean,balanced,vineyard,spicy,white,make,aroma,firm,apple,peach,cherry,balance,touch,fine,tannic,vanilla,pear,note,pinot,green,mouth,black,dark,hint,plum,palate,tart,feel,pepper,long,chocolate,offer,bit,blackberry,currant,herb,nose,black cherry,
#
# TF-IDF tfidf_word_0.2_0.85_3:
# fruit,wine,flavors,finish,aromas,cherry,tannins,palate,acidity,
# wine,acidity,flavors,tannins,cherry,aromas,fruit,finish,palate,
# flavors,finish,palate,aromas,cherry,tannins,wine,acidity,fruit,
#
# TF-IDF tfidf_stem_0.2_0.85_3:
# wine,flavor,cherri,acid,tannin,finish,aroma,fruit,palat,
# fruit,wine,flavor,acid,finish,tannin,cherri,aroma,palat,
# finish,palat,aroma,flavor,cherri,wine,acid,tannin,fruit,
#
# TF-IDF tfidf_lemm_0.2_0.85_3:
# fruit,wine,flavor,acidity,finish,tannin,cherry,aroma,palate,
# wine,flavor,cherry,acidity,tannin,finish,aroma,palate,fruit,
# flavor,finish,palate,aroma,cherry,tannin,acidity,fruit,wine,
#
# TF-IDF tfidf_word_0.15_0.85_3:
# wine,acidity,flavors,ripe,tannins,oak,cherry,black,finish,fruit,palate,aromas,
# flavors,finish,palate,aromas,cherry,tannins,black,oak,ripe,wine,acidity,fruit,
# fruit,wine,flavors,finish,aromas,oak,cherry,tannins,black,acidity,ripe,palate,
#
# TF-IDF tfidf_stem_0.15_0.85_3:
# finish,flavor,aroma,palat,note,fruit,wine,oak,acid,dri,spice,drink,ripe,rich,tannin,cherri,black,
# wine,fruit,acid,flavor,ripe,rich,drink,tannin,dri,spice,oak,finish,black,aroma,note,palat,cherri,
# cherri,black,tannin,flavor,wine,dri,spice,drink,oak,finish,acid,fruit,note,rich,palat,aroma,ripe,
#
# TF-IDF tfidf_lemm_0.15_0.85_3:
# finish,flavor,aroma,palate,note,fruit,wine,oak,spice,drink,acidity,ripe,tannin,cherry,black,
# wine,fruit,acidity,flavor,ripe,drink,tannin,spice,oak,finish,note,black,aroma,palate,cherry,
# cherry,black,tannin,flavor,wine,spice,oak,finish,fruit,note,drink,aroma,palate,ripe,acidity,
#
# TF-IDF tfidf_word_0.1_0.85_3:
# wine,flavors,acidity,dry,tannins,ripe,rich,sweet,cherry,oak,soft,drink,black,good,red,spice,finish,fresh,notes,aromas,palate,fruit,nose,
# palate,aromas,finish,nose,flavors,notes,cherry,wine,spice,fresh,black,oak,tannins,drink,acidity,ripe,good,sweet,red,fruit,soft,dry,rich,
# fruit,wine,flavors,finish,tannins,oak,black,cherry,aromas,ripe,acidity,red,drink,spice,notes,good,rich,fresh,dry,soft,sweet,palate,nose,
#
# TF-IDF tfidf_stem_0.1_0.85_3:
# wine,fruit,acid,flavor,ripe,rich,fresh,drink,dri,oak,spice,balanc,good,sweet,red,tannin,finish,soft,aroma,berri,cherri,note,black,plum,blackberri,palat,nose,
# cherri,black,tannin,flavor,blackberri,dri,wine,soft,spice,drink,oak,fruit,finish,plum,ripe,rich,sweet,acid,red,balanc,aroma,good,note,palat,nose,berri,fresh,
# finish,palat,aroma,flavor,note,nose,fruit,berri,sweet,acid,wine,oak,dri,plum,fresh,good,spice,drink,cherri,red,ripe,rich,balanc,soft,tannin,blackberri,black,
#
# TF-IDF tfidf_lemm_0.1_0.85_3:
# flavor,cherry,tannin,black,dry,wine,sweet,blackberry,oak,soft,spice,rich,good,finish,drink,ripe,acidity,fruit,red,plum,aroma,note,berry,palate,nose,fresh,
# wine,fruit,acidity,flavor,ripe,drink,fresh,tannin,red,rich,spice,finish,dry,oak,note,good,berry,black,cherry,aroma,soft,plum,sweet,blackberry,palate,nose,
# aroma,finish,palate,note,flavor,nose,berry,wine,fruit,plum,cherry,fresh,oak,drink,acidity,spice,good,red,ripe,tannin,sweet,black,dry,soft,blackberry,rich,
#
# TF-IDF tfidf_word_0.05_0.85_3:
# black,tannins,cherry,flavors,wine,fruit,blackberry,oak,dark,dry,chocolate,soft,finish,spice,ripe,rich,years,plum,red,shows,drink,aromas,firm,pepper,sweet,palate,good,tannic,fine,cherries,raspberry,structure,notes,pinot,mouth,spicy,vanilla,nose,like,offers,balanced,juicy,long,bit,berry,acidity,texture,touch,fresh,crisp,bright,fruity,style,green,fruits,tart,clean,light,white,citrus,apple,peach,
# aromas,finish,palate,flavors,nose,notes,fruit,apple,berry,bit,wine,green,citrus,peach,long,oak,white,spice,mouth,tart,light,plum,vanilla,fresh,sweet,acidity,drink,bright,good,offers,raspberry,shows,touch,cherry,ripe,red,clean,like,crisp,spicy,pinot,style,pepper,dry,rich,soft,chocolate,blackberry,tannins,texture,tannic,juicy,dark,balanced,fruits,firm,fruity,cherries,fine,structure,years,black,
# wine,acidity,flavors,ripe,fruit,fruits,crisp,rich,dry,drink,fresh,sweet,good,texture,fruity,oak,red,soft,vanilla,citrus,style,like,light,spice,clean,structure,cherries,finish,tannins,bright,balanced,apple,juicy,shows,years,pinot,white,tart,peach,fine,berry,green,touch,notes,raspberry,spicy,tannic,firm,cherry,mouth,offers,aromas,palate,pepper,bit,long,dark,black,plum,chocolate,blackberry,nose,
#
# TF-IDF tfidf_stem_0.05_0.85_3:
# wine,fruit,acid,flavor,ripe,rich,fresh,age,crisp,drink,structur,textur,dri,fruiti,spice,balanc,oak,red,miner,tannin,light,sweet,good,year,juici,soft,style,citrus,bright,make,like,berri,tast,white,peach,firm,finish,vineyard,toast,fine,appl,spici,eleg,touch,vanilla,pinot,cherri,complex,clean,pear,tannic,aroma,raspberri,hint,note,mouth,green,tart,dark,offer,smooth,plum,nice,chocol,feel,bit,blackberri,black,palat,pepper,long,currant,nose,herb,black cherri,
# cherri,black,tannin,flavor,blackberri,wine,dri,oak,currant,spice,fruit,black cherri,dark,drink,soft,chocol,plum,finish,rich,ripe,raspberri,red,aroma,sweet,note,year,pepper,pinot,balanc,acid,good,palat,complex,fine,offer,firm,herb,structur,nice,smooth,tannic,vanilla,age,like,vineyard,berri,spici,mouth,eleg,textur,tast,nose,bit,make,feel,hint,long,toast,fruiti,fresh,touch,juici,crisp,tart,bright,style,clean,light,green,white,miner,citrus,pear,peach,appl,
# finish,aroma,palat,flavor,note,nose,appl,fruit,berri,wine,sweet,green,acid,peach,bit,pear,citrus,vanilla,tart,oak,dri,hint,good,fresh,mouth,long,light,offer,spice,miner,plum,white,herb,feel,touch,clean,raspberri,drink,bright,ripe,cherri,crisp,soft,like,rich,red,toast,style,pepper,balanc,textur,nice,spici,tast,complex,eleg,pinot,chocol,make,tannin,tannic,smooth,blackberri,vineyard,fruiti,juici,dark,firm,structur,age,fine,year,black,currant,black cherri,
#
# TF-IDF tfidf_lemm_0.05_0.85_3:
# finish,flavor,aroma,palate,note,nose,apple,fruit,green,berry,peach,wine,citrus,sweet,pear,vanilla,good,hint,bit,oak,white,tart,long,mouth,fresh,acidity,light,touch,herb,spice,feel,drink,bright,offer,crisp,dry,plum,like,ripe,clean,raspberry,style,soft,cherry,pepper,pinot,red,rich,spicy,make,balanced,chocolate,balance,vineyard,texture,tannin,blackberry,tannic,juicy,dark,fruity,year,fine,firm,structure,black,currant,black cherry,
# cherry,black,tannin,flavor,blackberry,wine,currant,oak,black cherry,dry,plum,chocolate,fruit,dark,finish,spice,soft,red,aroma,drink,raspberry,note,rich,ripe,year,pepper,palate,good,pinot,sweet,herb,firm,fine,tannic,berry,vanilla,offer,vineyard,like,balance,acidity,bit,nose,spicy,structure,hint,long,mouth,texture,balanced,feel,make,juicy,fresh,touch,fruity,crisp,tart,bright,clean,style,green,white,light,citrus,pear,peach,apple,
# wine,fruit,acidity,flavor,ripe,rich,drink,spice,crisp,dry,red,texture,tannin,fresh,oak,fruity,structure,year,sweet,soft,juicy,style,berry,finish,light,good,citrus,bright,raspberry,balanced,vineyard,like,firm,clean,cherry,make,aroma,peach,spicy,balance,fine,vanilla,white,tannic,apple,touch,pinot,note,dark,pear,mouth,black,plum,tart,hint,feel,palate,green,chocolate,offer,long,bit,blackberry,pepper,currant,herb,nose,black cherry,
#
# TF-IDF tfidf_word_0.2_0.9_3:
# fruit,wine,flavors,finish,aromas,tannins,cherry,acidity,palate,
# wine,flavors,acidity,tannins,cherry,finish,aromas,palate,fruit,
# flavors,finish,palate,aromas,cherry,tannins,acidity,wine,fruit,
#
# TF-IDF tfidf_stem_0.2_0.9_3:
# fruit,wine,flavor,acid,finish,tannin,cherri,aroma,palat,
# flavor,finish,palat,aroma,cherri,acid,tannin,fruit,wine,
# wine,flavor,acid,cherri,tannin,finish,aroma,palat,fruit,
#
# TF-IDF tfidf_lemm_0.2_0.9_3:
# flavor,finish,aroma,palate,fruit,acidity,wine,tannin,cherry,
# cherry,flavor,tannin,wine,finish,fruit,aroma,palate,acidity,
# wine,fruit,flavor,acidity,tannin,finish,aroma,palate,cherry,
#
# TF-IDF tfidf_word_0.15_0.9_3:
# wine,flavors,acidity,fruit,ripe,tannins,finish,cherry,oak,black,aromas,palate,
# aromas,palate,finish,flavors,fruit,wine,cherry,acidity,tannins,oak,ripe,black,
# flavors,fruit,cherry,tannins,black,oak,finish,acidity,ripe,wine,palate,aromas,
#
# TF-IDF tfidf_stem_0.15_0.9_3:
# cherri,black,tannin,flavor,wine,dri,spice,oak,finish,drink,acid,fruit,note,rich,aroma,palat,ripe,
# wine,fruit,acid,flavor,ripe,rich,drink,tannin,dri,spice,oak,finish,black,aroma,note,palat,cherri,
# finish,flavor,aroma,palat,note,fruit,wine,oak,acid,dri,spice,drink,ripe,rich,tannin,cherri,black,
#
# TF-IDF tfidf_lemm_0.15_0.9_3:
# finish,flavor,aroma,palate,note,fruit,wine,oak,drink,spice,acidity,ripe,tannin,cherry,black,
# cherry,black,tannin,flavor,wine,spice,finish,oak,fruit,note,drink,aroma,palate,ripe,acidity,
# wine,fruit,acidity,flavor,ripe,drink,tannin,spice,oak,finish,black,note,aroma,cherry,palate,
#
# TF-IDF tfidf_word_0.1_0.9_3:
# wine,flavors,acidity,dry,tannins,ripe,rich,sweet,cherry,oak,black,soft,drink,good,red,finish,spice,fresh,notes,aromas,palate,fruit,nose,
# fruit,wine,flavors,finish,tannins,oak,black,cherry,aromas,ripe,acidity,red,drink,spice,notes,good,rich,fresh,dry,soft,sweet,palate,nose,
# aromas,palate,finish,nose,flavors,notes,cherry,wine,spice,fresh,black,drink,oak,tannins,acidity,ripe,good,sweet,red,soft,fruit,dry,rich,
#
# TF-IDF tfidf_stem_0.1_0.9_3:
# cherri,black,tannin,flavor,blackberri,dri,wine,soft,spice,drink,oak,fruit,finish,plum,rich,ripe,sweet,acid,red,balanc,aroma,good,note,palat,nose,berri,fresh,
# wine,fruit,acid,flavor,ripe,rich,fresh,drink,oak,dri,spice,good,balanc,sweet,tannin,red,finish,aroma,soft,berri,cherri,note,black,plum,blackberri,palat,nose,
# finish,palat,aroma,flavor,note,nose,fruit,berri,sweet,acid,wine,oak,plum,dri,fresh,good,spice,drink,cherri,red,ripe,rich,balanc,soft,tannin,blackberri,black,
#
# TF-IDF tfidf_lemm_0.1_0.9_3:
# flavor,cherry,tannin,dry,black,sweet,wine,oak,blackberry,soft,spice,rich,finish,good,drink,ripe,acidity,fruit,red,aroma,plum,note,berry,palate,fresh,nose,
# wine,fruit,acidity,flavor,ripe,fresh,drink,finish,tannin,rich,red,spice,dry,oak,good,black,aroma,berry,cherry,note,soft,plum,blackberry,sweet,palate,nose,
# palate,aroma,finish,note,nose,flavor,berry,fruit,plum,wine,cherry,oak,fresh,acidity,drink,tannin,red,spice,good,ripe,black,sweet,dry,blackberry,soft,rich,
#
# TF-IDF tfidf_word_0.05_0.9_3:
# finish,aromas,palate,flavors,nose,notes,fruit,apple,berry,bit,wine,green,peach,citrus,long,white,oak,mouth,tart,light,spice,plum,fresh,vanilla,drink,bright,acidity,shows,sweet,good,offers,raspberry,touch,cherry,clean,red,ripe,crisp,pinot,style,dry,like,pepper,soft,spicy,rich,chocolate,blackberry,tannins,texture,juicy,tannic,balanced,dark,fruits,firm,fruity,structure,fine,cherries,years,black,
# black,tannins,cherry,flavors,wine,fruit,blackberry,oak,dark,dry,chocolate,soft,finish,spice,years,rich,aromas,plum,ripe,shows,drink,red,firm,pepper,palate,tannic,good,fine,raspberry,cherries,sweet,notes,structure,pinot,nose,vanilla,mouth,spicy,like,offers,balanced,long,acidity,berry,bit,juicy,texture,touch,fresh,bright,crisp,fruits,fruity,green,style,tart,clean,light,white,citrus,apple,peach,
# wine,acidity,flavors,ripe,fruit,crisp,fruits,sweet,rich,dry,drink,fresh,good,texture,red,oak,fruity,soft,vanilla,citrus,like,style,spice,cherries,light,structure,clean,tannins,juicy,bright,balanced,pinot,apple,shows,finish,years,white,tart,peach,fine,berry,spicy,raspberry,green,touch,notes,cherry,tannic,firm,mouth,offers,aromas,palate,bit,pepper,dark,plum,long,black,chocolate,blackberry,nose,
#
# TF-IDF tfidf_stem_0.05_0.9_3:
# wine,fruit,acid,flavor,ripe,rich,fresh,drink,age,crisp,textur,structur,spice,oak,dri,balanc,tannin,fruiti,red,light,sweet,miner,year,soft,juici,style,good,bright,make,berri,cherri,citrus,like,firm,tast,raspberri,vineyard,toast,vanilla,fine,finish,eleg,touch,pinot,peach,appl,white,aroma,complex,clean,spici,tannic,note,pear,mouth,hint,tart,nice,plum,dark,green,offer,feel,smooth,chocol,palat,blackberri,black,bit,long,currant,pepper,herb,nose,black cherri,
# cherri,black,tannin,flavor,blackberri,wine,dri,currant,fruit,oak,black cherri,dark,spice,chocol,finish,soft,drink,plum,rich,red,aroma,ripe,sweet,note,raspberri,pepper,year,good,palat,pinot,complex,balanc,offer,fine,acid,herb,smooth,tannic,structur,firm,berri,nice,like,age,spici,vanilla,vineyard,nose,eleg,tast,mouth,bit,hint,textur,long,feel,make,toast,fruiti,juici,touch,fresh,crisp,bright,tart,clean,style,light,green,white,miner,citrus,peach,pear,appl,
# finish,flavor,palat,aroma,note,nose,appl,fruit,wine,berri,acid,sweet,green,peach,citrus,bit,pear,good,oak,tart,vanilla,dri,fresh,hint,light,white,mouth,long,offer,miner,spice,plum,feel,touch,herb,raspberri,clean,drink,ripe,bright,crisp,cherri,like,rich,soft,style,toast,red,pepper,nice,textur,balanc,spici,tast,pinot,eleg,complex,make,chocol,vineyard,tannin,smooth,blackberri,juici,fruiti,tannic,dark,firm,structur,age,fine,year,currant,black,black cherri,
#
# TF-IDF tfidf_lemm_0.05_0.9_3:
# cherry,black,tannin,flavor,blackberry,wine,currant,oak,black cherry,dry,chocolate,plum,fruit,soft,spice,finish,dark,drink,aroma,rich,year,raspberry,note,pinot,sweet,pepper,red,ripe,good,palate,fine,herb,firm,tannic,vanilla,offer,like,vineyard,balance,bit,nose,acidity,structure,berry,spicy,mouth,feel,hint,long,texture,make,balanced,juicy,fresh,touch,fruity,crisp,clean,bright,style,tart,green,white,light,citrus,peach,apple,pear,
# finish,aroma,palate,flavor,note,nose,fruit,apple,berry,peach,green,wine,vanilla,bit,pear,hint,citrus,good,oak,sweet,tart,long,white,mouth,fresh,herb,light,spice,acidity,plum,touch,feel,offer,drink,bright,ripe,dry,crisp,raspberry,cherry,clean,like,red,soft,style,pepper,rich,pinot,spicy,chocolate,make,tannin,balanced,blackberry,vineyard,texture,balance,tannic,juicy,dark,fruity,year,firm,fine,structure,black,currant,black cherry,
# wine,fruit,acidity,flavor,ripe,rich,drink,crisp,spice,dry,red,fresh,texture,tannin,oak,fruity,structure,sweet,year,light,good,citrus,soft,style,juicy,finish,berry,bright,raspberry,balanced,like,vineyard,clean,firm,peach,spicy,cherry,make,white,aroma,apple,balance,vanilla,touch,tannic,fine,pear,dark,pinot,note,green,mouth,black,hint,plum,tart,palate,feel,offer,chocolate,pepper,blackberry,bit,long,currant,herb,nose,black cherry,
#
# TF-IDF tfidf_word_0.2_0.95_3:
# flavors,finish,palate,aromas,cherry,tannins,acidity,wine,fruit,
# wine,flavors,acidity,tannins,cherry,finish,aromas,palate,fruit,
# fruit,wine,flavors,finish,aromas,cherry,tannins,acidity,palate,
#
# TF-IDF tfidf_stem_0.2_0.95_3:
# flavor,finish,palat,aroma,cherri,acid,tannin,fruit,wine,
# fruit,wine,flavor,acid,finish,tannin,cherri,aroma,palat,
# wine,flavor,acid,cherri,tannin,finish,aroma,palat,fruit,
#
# TF-IDF tfidf_lemm_0.2_0.95_3:
# cherry,flavor,wine,tannin,finish,fruit,aroma,palate,acidity,
# wine,fruit,acidity,flavor,tannin,finish,aroma,palate,cherry,
# flavor,finish,aroma,palate,tannin,wine,fruit,acidity,cherry,
#
# TF-IDF tfidf_word_0.15_0.95_3:
# wine,acidity,flavors,ripe,tannins,cherry,oak,finish,black,aromas,palate,fruit,
# fruit,wine,flavors,finish,aromas,oak,cherry,tannins,black,ripe,acidity,palate,
# flavors,finish,palate,aromas,cherry,tannins,black,oak,acidity,ripe,wine,fruit,
#
# TF-IDF tfidf_stem_0.15_0.95_3:
# wine,fruit,acid,flavor,ripe,rich,drink,spice,oak,dri,tannin,finish,black,note,aroma,cherri,palat,
# finish,aroma,flavor,palat,note,fruit,wine,oak,acid,dri,spice,drink,ripe,rich,cherri,tannin,black,
# cherri,black,tannin,flavor,dri,wine,drink,spice,oak,acid,finish,fruit,rich,ripe,note,aroma,palat,
#
# TF-IDF tfidf_lemm_0.15_0.95_3:
# cherry,tannin,black,flavor,wine,spice,oak,finish,fruit,drink,note,aroma,ripe,palate,acidity,
# finish,flavor,aroma,palate,note,fruit,wine,oak,spice,drink,acidity,ripe,tannin,cherry,black,
# wine,fruit,acidity,flavor,ripe,drink,spice,oak,tannin,finish,cherry,note,black,aroma,palate,
#
# TF-IDF tfidf_word_0.1_0.95_3:
# fruit,wine,flavors,finish,aromas,oak,cherry,tannins,black,red,ripe,spice,notes,acidity,drink,palate,good,fresh,rich,nose,soft,dry,sweet,
# flavors,finish,palate,aromas,nose,cherry,notes,tannins,black,sweet,oak,dry,soft,drink,good,spice,wine,red,fresh,ripe,acidity,rich,fruit,
# wine,acidity,flavors,rich,ripe,dry,tannins,drink,oak,cherry,fresh,good,spice,sweet,black,red,soft,finish,aromas,fruit,notes,palate,nose,
#
# TF-IDF tfidf_stem_0.1_0.95_3:
# wine,fruit,acid,flavor,ripe,rich,fresh,drink,spice,oak,dri,balanc,good,sweet,red,tannin,finish,soft,berri,aroma,cherri,note,black,plum,blackberri,palat,nose,
# cherri,black,tannin,flavor,blackberri,dri,wine,soft,spice,drink,oak,fruit,finish,plum,ripe,rich,acid,sweet,red,balanc,aroma,good,note,palat,nose,berri,fresh,
# finish,aroma,palat,flavor,note,nose,berri,fruit,wine,sweet,acid,oak,dri,plum,fresh,spice,good,cherri,drink,red,ripe,rich,balanc,soft,tannin,blackberri,black,
#
# TF-IDF tfidf_lemm_0.1_0.95_3:
# wine,fruit,acidity,flavor,ripe,drink,fresh,tannin,spice,rich,red,dry,finish,oak,berry,good,black,note,cherry,aroma,soft,plum,blackberry,sweet,palate,nose,
# aroma,finish,palate,note,flavor,nose,fruit,berry,wine,plum,cherry,fresh,oak,drink,acidity,good,red,tannin,spice,ripe,black,sweet,dry,blackberry,soft,rich,
# flavor,cherry,tannin,black,oak,dry,sweet,wine,blackberry,soft,spice,rich,good,drink,finish,ripe,acidity,fruit,red,plum,note,aroma,berry,palate,fresh,nose,
#
# TF-IDF tfidf_word_0.05_0.95_3:
# finish,aromas,palate,flavors,nose,notes,fruit,apple,bit,berry,wine,green,citrus,peach,long,oak,mouth,tart,light,plum,white,fresh,spice,vanilla,bright,drink,acidity,sweet,shows,good,raspberry,offers,touch,cherry,clean,red,ripe,crisp,like,spicy,dry,pepper,style,pinot,chocolate,rich,soft,blackberry,texture,tannins,juicy,tannic,balanced,dark,fruits,firm,fruity,cherries,structure,fine,years,black,
# black,tannins,cherry,flavors,wine,fruit,blackberry,oak,dark,chocolate,dry,finish,spice,soft,plum,shows,aromas,ripe,years,drink,rich,firm,pepper,red,palate,good,fine,tannic,notes,raspberry,structure,sweet,cherries,vanilla,nose,spicy,mouth,offers,like,balanced,berry,pinot,long,juicy,acidity,bit,texture,touch,fresh,bright,fruits,crisp,style,green,fruity,tart,white,clean,light,citrus,peach,apple,
# wine,acidity,flavors,ripe,fruit,rich,sweet,dry,crisp,fruits,drink,good,fresh,soft,oak,texture,red,fruity,vanilla,cherries,citrus,spice,pinot,style,like,light,clean,structure,tannins,juicy,bright,balanced,white,years,shows,apple,finish,peach,berry,fine,tart,raspberry,green,touch,cherry,notes,tannic,spicy,mouth,offers,firm,aromas,palate,pepper,long,bit,dark,plum,black,chocolate,blackberry,nose,
#
# TF-IDF tfidf_stem_0.05_0.95_3:
# cherri,black,tannin,flavor,blackberri,wine,dri,black cherri,currant,soft,spice,oak,drink,chocol,raspberri,finish,plum,dark,fruit,rich,sweet,aroma,ripe,note,pepper,pinot,acid,red,year,balanc,palat,fine,good,complex,offer,herb,nice,smooth,structur,tannic,firm,vanilla,like,age,vineyard,textur,eleg,spici,nose,mouth,bit,feel,tast,hint,berri,make,long,fresh,fruiti,juici,touch,crisp,toast,clean,light,tart,style,bright,green,white,miner,citrus,pear,appl,peach,
# finish,palat,aroma,flavor,note,nose,appl,fruit,berri,wine,sweet,acid,peach,green,bit,pear,citrus,oak,tart,vanilla,dri,good,hint,mouth,fresh,white,long,light,offer,miner,plum,spice,herb,drink,feel,touch,bright,clean,raspberri,ripe,crisp,rich,soft,cherri,red,like,toast,style,pepper,balanc,chocol,textur,nice,pinot,eleg,spici,tast,complex,make,tannin,blackberri,vineyard,dark,smooth,tannic,firm,fruiti,juici,structur,age,fine,year,black,currant,black cherri,
# wine,fruit,acid,flavor,ripe,rich,drink,fresh,age,crisp,structur,textur,tannin,red,spice,oak,dri,balanc,fruiti,year,miner,good,light,sweet,juici,style,bright,berri,citrus,soft,make,like,firm,tast,finish,toast,vineyard,spici,touch,fine,complex,eleg,peach,white,appl,aroma,vanilla,tannic,dark,pinot,note,cherri,clean,pear,mouth,black,hint,smooth,raspberri,green,plum,tart,offer,nice,feel,chocol,bit,palat,long,blackberri,currant,pepper,nose,herb,black cherri,
#
# TF-IDF tfidf_lemm_0.05_0.95_3:
# wine,fruit,acidity,flavor,ripe,rich,crisp,drink,spice,dry,oak,fresh,red,texture,good,tannin,sweet,structure,fruity,citrus,year,berry,light,style,finish,juicy,soft,bright,peach,raspberry,balanced,like,clean,apple,vanilla,white,vineyard,cherry,balance,firm,aroma,make,spicy,touch,pear,fine,tannic,note,dark,pinot,mouth,green,tart,hint,plum,feel,black,palate,bit,offer,chocolate,pepper,blackberry,long,currant,herb,nose,black cherry,
# cherry,black,tannin,flavor,blackberry,wine,currant,dry,black cherry,oak,chocolate,fruit,soft,plum,spice,dark,finish,drink,rich,note,year,aroma,sweet,raspberry,red,pinot,ripe,pepper,good,palate,fine,herb,firm,tannic,vanilla,offer,vineyard,like,balance,structure,spicy,nose,acidity,berry,bit,mouth,hint,feel,balanced,texture,make,juicy,long,fresh,touch,fruity,crisp,clean,bright,tart,style,green,white,light,citrus,pear,apple,peach,
# finish,aroma,palate,flavor,note,nose,fruit,apple,berry,green,peach,wine,bit,hint,long,pear,citrus,vanilla,oak,tart,mouth,sweet,white,plum,herb,fresh,light,spice,acidity,offer,touch,drink,feel,good,bright,raspberry,cherry,ripe,like,soft,clean,dry,red,style,crisp,pepper,pinot,chocolate,spicy,rich,make,tannin,blackberry,vineyard,tannic,balanced,texture,dark,juicy,balance,fruity,year,firm,fine,structure,black,currant,black cherry,
#
# TF-IDF tfidf_word_0.2_0.8_4:
# flavors,finish,palate,aromas,cherry,tannins,wine,acidity,fruit,
# fruit,wine,flavors,finish,aromas,cherry,tannins,palate,acidity,
# wine,flavors,tannins,cherry,finish,aromas,palate,fruit,acidity,
# acidity,wine,flavors,fruit,tannins,finish,cherry,palate,aromas,
#
# TF-IDF tfidf_stem_0.2_0.8_4:
# fruit,wine,flavor,acid,finish,tannin,aroma,palat,cherri,
# flavor,finish,palat,aroma,acid,tannin,fruit,wine,cherri,
# cherri,flavor,tannin,wine,finish,acid,fruit,palat,aroma,
# wine,flavor,acid,tannin,finish,aroma,fruit,palat,cherri,
#
# TF-IDF tfidf_lemm_0.2_0.8_4:
# wine,flavor,acidity,tannin,finish,aroma,fruit,cherry,palate,
# flavor,finish,palate,aroma,acidity,tannin,wine,fruit,cherry,
# fruit,wine,flavor,acidity,finish,tannin,aroma,palate,cherry,
# cherry,tannin,flavor,wine,finish,fruit,aroma,palate,acidity,
#
# TF-IDF tfidf_word_0.15_0.8_4:
# wine,fruit,acidity,flavors,ripe,tannins,cherry,black,aromas,palate,finish,oak,
# flavors,aromas,palate,cherry,tannins,black,fruit,ripe,acidity,wine,finish,oak,
# finish,flavors,aromas,fruit,palate,wine,cherry,tannins,acidity,black,ripe,oak,
# oak,flavors,wine,fruit,cherry,finish,tannins,ripe,black,acidity,aromas,palate,
#
# TF-IDF tfidf_stem_0.15_0.8_4:
# note,finish,palat,fruit,flavor,cherri,wine,aroma,tannin,oak,acid,drink,spice,black,ripe,dri,rich,
# aroma,palat,finish,flavor,wine,fruit,acid,cherri,spice,oak,ripe,drink,dri,tannin,rich,black,note,
# fruit,wine,acid,ripe,flavor,tannin,drink,rich,spice,finish,black,oak,dri,cherri,aroma,palat,note,
# flavor,cherri,wine,dri,acid,tannin,oak,black,finish,rich,drink,spice,ripe,fruit,palat,aroma,note,
#
# TF-IDF tfidf_lemm_0.15_0.8_4:
# cherry,black,tannin,flavor,wine,oak,spice,finish,drink,fruit,ripe,acidity,palate,aroma,note,
# wine,fruit,acidity,flavor,ripe,drink,spice,tannin,oak,finish,black,cherry,aroma,palate,note,
# note,finish,palate,fruit,flavor,wine,aroma,cherry,oak,tannin,drink,spice,acidity,ripe,black,
# flavor,aroma,finish,palate,wine,fruit,oak,acidity,spice,drink,ripe,tannin,cherry,black,note,
#
# TF-IDF tfidf_word_0.1_0.8_4:
# wine,acidity,flavors,ripe,drink,rich,fresh,tannins,dry,spice,black,red,finish,aromas,cherry,oak,fruit,good,soft,notes,sweet,palate,nose,
# flavors,sweet,dry,oak,cherry,tannins,soft,good,black,finish,rich,acidity,ripe,wine,drink,red,spice,notes,aromas,fruit,palate,fresh,nose,
# palate,aromas,nose,finish,flavors,notes,cherry,wine,fresh,acidity,black,drink,ripe,tannins,spice,oak,red,good,fruit,dry,sweet,soft,rich,
# fruit,wine,finish,flavors,tannins,black,cherry,oak,aromas,red,spice,notes,ripe,drink,acidity,good,rich,fresh,dry,palate,nose,soft,sweet,
#
# TF-IDF tfidf_stem_0.1_0.8_4:
# wine,fruit,acid,flavor,ripe,fresh,rich,drink,spice,dri,balanc,oak,good,red,tannin,finish,berri,soft,aroma,note,cherri,black,plum,blackberri,palat,nose,sweet,
# sweet,flavor,wine,acid,finish,fruit,cherri,soft,oak,aroma,ripe,rich,good,drink,note,palat,spice,tannin,balanc,blackberri,dri,plum,nose,red,fresh,berri,black,
# cherri,black,tannin,flavor,dri,blackberri,wine,spice,soft,drink,fruit,finish,plum,oak,rich,acid,ripe,aroma,note,red,balanc,good,palat,nose,berri,fresh,sweet,
# finish,palat,aroma,flavor,note,nose,berri,fruit,wine,oak,acid,dri,plum,fresh,spice,red,cherri,good,drink,ripe,rich,blackberri,tannin,balanc,soft,black,sweet,
#
# TF-IDF tfidf_lemm_0.1_0.8_4:
# note,finish,palate,fruit,cherry,wine,flavor,aroma,nose,tannin,oak,drink,spice,black,acidity,ripe,berry,plum,red,fresh,sweet,rich,good,blackberry,dry,soft,
# flavor,wine,cherry,dry,acidity,sweet,oak,tannin,rich,blackberry,soft,ripe,spice,drink,black,finish,good,fresh,red,plum,berry,fruit,aroma,palate,nose,note,
# aroma,palate,finish,flavor,nose,wine,berry,plum,cherry,fruit,fresh,good,spice,black,tannin,acidity,ripe,drink,oak,sweet,red,soft,blackberry,dry,rich,note,
# fruit,wine,acidity,flavor,red,ripe,tannin,black,drink,finish,spice,oak,rich,fresh,cherry,good,berry,dry,aroma,plum,soft,blackberry,palate,nose,sweet,note,
#
# TF-IDF tfidf_word_0.05_0.8_4:
# cherry,black,tannins,flavors,fruit,dark,wine,plum,blackberry,aromas,finish,chocolate,palate,oak,pepper,raspberry,spice,ripe,red,shows,nose,soft,drink,vanilla,notes,dry,berry,good,firm,tannic,rich,years,offers,long,spicy,juicy,mouth,bit,balanced,acidity,bright,like,fresh,touch,fine,structure,pinot,cherries,texture,crisp,tart,style,clean,fruity,green,white,fruits,light,sweet,citrus,peach,apple,
# wine,acidity,flavors,dry,ripe,fruit,rich,drink,fruits,tannins,crisp,red,oak,texture,fresh,years,soft,structure,good,spice,fruity,cherries,fine,shows,pinot,firm,juicy,like,tannic,berry,balanced,clean,light,cherry,citrus,vanilla,style,spicy,black,bright,finish,green,notes,blackberry,white,mouth,bit,apple,tart,touch,chocolate,aromas,raspberry,offers,dark,peach,pepper,palate,long,plum,nose,sweet,
# sweet,flavors,wine,oak,soft,acidity,good,ripe,finish,fruit,cherry,rich,aromas,like,tannins,vanilla,cherries,raspberry,style,drink,pinot,blackberry,notes,bit,crisp,palate,spice,balanced,apple,fruity,dry,shows,mouth,fine,black,years,plum,spicy,chocolate,nose,fruits,tart,red,long,offers,citrus,structure,peach,white,touch,texture,juicy,pepper,tannic,fresh,berry,light,green,firm,clean,bright,dark,
# finish,palate,aromas,flavors,fruit,notes,nose,apple,wine,citrus,peach,green,white,light,bit,fresh,oak,berry,tart,mouth,long,spice,acidity,good,vanilla,bright,touch,shows,clean,offers,drink,ripe,style,like,crisp,pinot,red,pepper,raspberry,dry,soft,spicy,rich,plum,texture,chocolate,blackberry,cherry,fruits,balanced,juicy,tannic,fruity,sweet,structure,tannins,cherries,fine,firm,years,dark,black,
#
# TF-IDF tfidf_stem_0.05_0.8_4:
# sweet,flavor,wine,finish,soft,acid,cherri,oak,fruit,raspberri,ripe,aroma,good,rich,drink,note,like,vanilla,spice,tast,style,palat,balanc,tannin,peach,blackberri,pear,appl,pinot,bit,fruiti,dri,touch,crisp,plum,mouth,toast,vineyard,hint,miner,spici,long,offer,complex,nose,citrus,tart,feel,white,nice,fine,textur,year,fresh,herb,currant,firm,red,green,light,age,chocol,berri,structur,eleg,smooth,black,clean,make,bright,tannic,pepper,juici,dark,black cherri,
# wine,fruit,acid,flavor,ripe,rich,drink,age,fresh,dri,crisp,textur,structur,tannin,spice,red,balanc,oak,cherri,year,light,good,fruiti,make,soft,miner,pinot,like,style,juici,bright,citrus,berri,firm,vineyard,complex,raspberri,fine,eleg,tast,finish,dark,vanilla,white,aroma,note,peach,spici,nice,tannic,toast,clean,touch,appl,plum,smooth,mouth,blackberri,hint,green,chocol,pear,offer,tart,feel,bit,herb,palat,currant,black,long,pepper,nose,sweet,black cherri,
# finish,aroma,palat,flavor,note,nose,fruit,berri,appl,wine,acid,green,oak,cherri,bit,dri,tart,vanilla,mouth,fresh,peach,spice,plum,hint,offer,herb,citrus,light,pear,long,good,raspberri,feel,touch,white,miner,bright,clean,ripe,red,drink,chocol,crisp,rich,dark,tannin,pepper,toast,like,soft,blackberri,nice,eleg,spici,complex,textur,tast,pinot,style,make,balanc,smooth,tannic,vineyard,juici,firm,fruiti,structur,age,year,fine,currant,sweet,black,black cherri,
# black,cherri,tannin,flavor,blackberri,black cherri,currant,wine,dri,drink,spice,plum,chocol,soft,finish,pepper,oak,ripe,rich,fruit,dark,palat,year,aroma,red,fine,offer,firm,good,note,complex,balanc,structur,tannic,acid,smooth,spici,nose,herb,age,nice,raspberri,berri,eleg,long,hint,pinot,vineyard,like,vanilla,fruiti,textur,bit,juici,tast,feel,mouth,toast,fresh,make,sweet,touch,crisp,bright,clean,white,miner,tart,green,light,style,citrus,pear,appl,peach,
#
# TF-IDF tfidf_lemm_0.05_0.8_4:
# black,black cherry,cherry,tannin,wine,fruit,flavor,currant,plum,palate,finish,ripe,pepper,blackberry,spice,aroma,chocolate,oak,drink,dark,red,note,dry,year,rich,nose,soft,firm,good,spicy,offer,fine,tannic,raspberry,herb,berry,juicy,vanilla,vineyard,long,acidity,hint,structure,balanced,pinot,sweet,like,balance,touch,make,mouth,feel,fruity,bit,texture,fresh,clean,crisp,bright,tart,light,green,white,style,citrus,pear,peach,apple,
# wine,fruit,acidity,ripe,flavor,rich,tannin,drink,spice,crisp,red,dry,fresh,year,texture,structure,fruity,juicy,light,berry,finish,style,bright,soft,firm,good,fine,vineyard,cherry,aroma,balanced,citrus,white,like,balance,clean,make,oak,sweet,touch,tannic,note,plum,dark,spicy,vanilla,mouth,raspberry,hint,peach,blackberry,apple,pear,feel,chocolate,green,tart,palate,offer,pinot,bit,currant,pepper,long,black,nose,herb,black cherry,
# flavor,cherry,oak,tannin,finish,blackberry,berry,wine,aroma,sweet,raspberry,plum,fruit,note,dry,soft,vanilla,spice,good,chocolate,dark,red,palate,pinot,herb,rich,bit,drink,ripe,acidity,mouth,currant,nose,feel,tannic,like,year,tart,offer,spicy,balance,long,pepper,texture,vineyard,hint,balanced,firm,fresh,make,structure,bright,fine,crisp,touch,style,green,clean,fruity,juicy,white,light,black,citrus,pear,peach,black cherry,apple,
# finish,palate,apple,flavor,aroma,peach,note,nose,citrus,pear,fruit,green,wine,white,acidity,hint,light,fresh,crisp,good,touch,long,clean,sweet,ripe,tart,drink,dry,like,bit,style,mouth,bright,oak,spice,offer,vanilla,soft,feel,herb,pepper,pinot,rich,make,texture,balanced,vineyard,fruity,spicy,raspberry,balance,juicy,red,berry,year,fine,firm,plum,structure,tannic,chocolate,cherry,currant,tannin,blackberry,black,dark,black cherry,
#
# TF-IDF tfidf_word_0.2_0.85_4:
# wine,flavors,acidity,tannins,cherry,finish,aromas,fruit,palate,
# palate,aromas,flavors,finish,cherry,wine,tannins,fruit,acidity,
# fruit,wine,flavors,finish,tannins,cherry,aromas,acidity,palate,
# flavors,finish,tannins,cherry,acidity,aromas,wine,fruit,palate,
#
# TF-IDF tfidf_stem_0.2_0.85_4:
# wine,fruit,flavor,acid,tannin,finish,aroma,cherri,palat,
# palat,aroma,finish,flavor,fruit,wine,acid,cherri,tannin,
# flavor,finish,fruit,aroma,acid,tannin,wine,cherri,palat,
# cherri,flavor,tannin,wine,finish,acid,fruit,aroma,palat,
#
# TF-IDF tfidf_lemm_0.2_0.85_4:
# wine,flavor,acidity,tannin,finish,aroma,fruit,palate,cherry,
# cherry,tannin,flavor,wine,acidity,finish,fruit,palate,aroma,
# fruit,wine,flavor,acidity,finish,tannin,aroma,palate,cherry,
# flavor,finish,aroma,palate,acidity,fruit,wine,tannin,cherry,
#
# TF-IDF tfidf_word_0.15_0.85_4:
# wine,flavors,fruit,ripe,oak,finish,tannins,cherry,aromas,black,palate,acidity,
# flavors,aromas,finish,palate,wine,fruit,cherry,ripe,oak,tannins,black,acidity,
# fruit,black,cherry,tannins,flavors,oak,ripe,finish,wine,palate,aromas,acidity,
# acidity,wine,flavors,ripe,fruit,tannins,finish,palate,oak,cherry,aromas,black,
#
# TF-IDF tfidf_stem_0.15_0.85_4:
# oak,flavor,wine,fruit,cherri,finish,tannin,acid,rich,ripe,note,aroma,dri,spice,palat,drink,black,
# wine,fruit,acid,flavor,ripe,rich,drink,spice,dri,tannin,finish,black,aroma,cherri,note,palat,oak,
# finish,aroma,palat,flavor,note,fruit,wine,acid,dri,drink,spice,ripe,cherri,rich,tannin,black,oak,
# cherri,flavor,black,tannin,dri,wine,spice,drink,finish,acid,aroma,fruit,rich,ripe,palat,note,oak,
#
# TF-IDF tfidf_lemm_0.15_0.85_4:
# aroma,flavor,palate,finish,wine,fruit,spice,cherry,acidity,note,tannin,drink,ripe,oak,black,
# finish,flavor,note,palate,oak,fruit,drink,wine,ripe,spice,acidity,tannin,cherry,aroma,black,
# cherry,black,tannin,flavor,wine,spice,oak,finish,fruit,drink,note,ripe,palate,acidity,aroma,
# wine,fruit,acidity,flavor,ripe,drink,spice,tannin,oak,finish,cherry,black,palate,note,aroma,
#
# TF-IDF tfidf_word_0.1_0.85_4:
# wine,acidity,flavors,fruit,ripe,dry,rich,drink,tannins,fresh,spice,cherry,red,oak,finish,good,sweet,notes,soft,palate,aromas,nose,black,
# flavors,finish,fruit,oak,notes,nose,palate,sweet,soft,good,cherry,tannins,ripe,dry,drink,red,acidity,spice,rich,fresh,wine,aromas,black,
# black,tannins,cherry,wine,fruit,flavors,ripe,finish,palate,aromas,oak,drink,dry,rich,red,spice,soft,nose,good,acidity,notes,sweet,fresh,
# aromas,flavors,palate,finish,wine,fruit,cherry,notes,acidity,fresh,spice,nose,tannins,sweet,oak,good,red,drink,dry,ripe,rich,soft,black,
#
# TF-IDF tfidf_stem_0.1_0.85_4:
# finish,palat,aroma,note,nose,flavor,fruit,berri,acid,wine,plum,cherri,fresh,spice,dri,red,oak,drink,good,ripe,tannin,sweet,rich,balanc,soft,blackberri,black,
# flavor,sweet,oak,cherri,soft,dri,acid,wine,blackberri,rich,spice,good,finish,tannin,drink,ripe,fruit,balanc,aroma,note,red,plum,berri,fresh,palat,nose,black,
# wine,fruit,acid,fresh,flavor,ripe,drink,rich,tannin,dri,red,balanc,spice,finish,cherri,berri,aroma,good,note,plum,oak,soft,blackberri,sweet,palat,nose,black,
# black,cherri,tannin,wine,fruit,flavor,plum,finish,palat,ripe,spice,dri,drink,aroma,blackberri,oak,rich,red,note,soft,nose,balanc,acid,good,berri,sweet,fresh,
#
# TF-IDF tfidf_lemm_0.1_0.85_4:
# fruit,wine,flavor,acidity,ripe,red,finish,drink,tannin,oak,spice,note,fresh,rich,aroma,good,cherry,berry,dry,plum,soft,blackberry,nose,palate,sweet,black,
# wine,flavor,cherry,dry,acidity,sweet,tannin,oak,rich,soft,blackberry,spice,ripe,good,drink,finish,fresh,aroma,note,berry,red,plum,fruit,palate,nose,black,
# black,cherry,tannin,wine,fruit,flavor,finish,plum,ripe,blackberry,spice,palate,aroma,drink,oak,rich,note,dry,red,soft,nose,good,acidity,sweet,berry,fresh,
# palate,aroma,finish,nose,note,flavor,berry,wine,plum,cherry,fresh,acidity,fruit,spice,oak,drink,red,ripe,good,tannin,sweet,dry,soft,blackberry,rich,black,
#
# TF-IDF tfidf_word_0.05_0.85_4:
# palate,aromas,finish,flavors,nose,notes,apple,berry,green,peach,wine,bit,white,citrus,fresh,tart,long,light,plum,mouth,spice,oak,sweet,acidity,raspberry,vanilla,offers,drink,good,bright,clean,touch,ripe,cherry,fruit,shows,like,crisp,dry,pinot,red,pepper,style,rich,soft,chocolate,spicy,blackberry,tannins,dark,fruits,balanced,juicy,texture,tannic,fruity,firm,fine,cherries,years,structure,black,
# wine,acidity,ripe,flavors,fruits,crisp,rich,dry,drink,sweet,fresh,good,fruity,texture,oak,red,vanilla,tannins,fruit,citrus,spice,clean,soft,light,shows,like,cherries,structure,style,finish,juicy,years,bright,fine,apple,balanced,tart,white,pinot,peach,firm,berry,green,touch,raspberry,tannic,notes,spicy,cherry,black,mouth,aromas,offers,pepper,bit,dark,long,plum,chocolate,palate,blackberry,nose,
# fruit,wine,flavors,finish,aromas,oak,cherry,tannins,red,spice,ripe,drink,dark,black,notes,mouth,rich,good,chocolate,berry,plum,shows,citrus,vanilla,palate,style,texture,fresh,spicy,bit,long,crisp,soft,light,raspberry,balanced,dry,bright,years,sweet,nose,structure,juicy,offers,like,tart,blackberry,acidity,pinot,pepper,tannic,touch,firm,white,clean,green,apple,fine,peach,cherries,fruits,fruity,
# black,cherry,tannins,flavors,wine,blackberry,soft,dry,oak,chocolate,finish,rich,dark,shows,years,sweet,plum,pepper,cherries,ripe,spice,drink,firm,red,tannic,good,palate,aromas,fine,structure,pinot,spicy,vanilla,raspberry,notes,like,nose,fruit,bit,offers,mouth,long,acidity,balanced,texture,juicy,touch,berry,fruity,bright,fresh,crisp,green,style,fruits,tart,clean,light,white,peach,apple,citrus,
#
# TF-IDF tfidf_stem_0.05_0.85_4:
# finish,palat,appl,flavor,note,aroma,nose,peach,citrus,green,pear,fruit,acid,miner,white,hint,wine,fresh,sweet,dri,tart,light,crisp,clean,long,good,touch,offer,bright,drink,bit,mouth,spice,ripe,like,style,rich,oak,vanilla,toast,herb,feel,eleg,balanc,soft,textur,pepper,tast,make,pinot,spici,fruiti,nice,complex,vineyard,raspberri,juici,cherri,red,age,smooth,berri,fine,structur,plum,tannic,firm,year,chocol,currant,blackberri,tannin,dark,black,black cherri,
# flavor,cherri,oak,tannin,finish,aroma,berri,wine,blackberri,fruit,sweet,raspberri,soft,dri,plum,spice,good,note,vanilla,red,dark,acid,drink,chocol,palat,rich,ripe,bit,pinot,herb,mouth,balanc,nice,like,offer,feel,nose,complex,currant,tast,smooth,textur,firm,year,tannic,structur,long,eleg,tart,pepper,spici,toast,hint,make,fine,vineyard,fresh,style,light,touch,bright,age,crisp,clean,fruiti,juici,white,green,miner,pear,peach,black,citrus,black cherri,appl,
# wine,fruit,acid,flavor,ripe,rich,fresh,age,drink,crisp,textur,dri,structur,tannin,spice,red,fruiti,light,year,balanc,miner,juici,bright,style,berri,make,soft,finish,fine,citrus,sweet,vineyard,good,firm,cherri,touch,complex,like,spici,oak,white,clean,toast,tannic,tast,peach,aroma,appl,eleg,pinot,pear,offer,hint,vanilla,note,mouth,plum,raspberri,chocol,green,blackberri,tart,dark,bit,feel,smooth,nice,palat,pepper,currant,black,long,nose,herb,black cherri,
# black,black cherri,cherri,tannin,wine,fruit,flavor,currant,plum,ripe,finish,palat,pepper,spice,blackberri,dri,aroma,drink,chocol,oak,dark,rich,red,note,year,nose,soft,firm,structur,complex,offer,fine,balanc,acid,age,spici,good,tannic,raspberri,smooth,herb,juici,berri,vineyard,vanilla,long,hint,sweet,eleg,fruiti,pinot,fresh,like,mouth,make,toast,touch,nice,tast,feel,textur,bit,crisp,tart,clean,bright,miner,light,white,green,style,citrus,appl,pear,peach,
#
# TF-IDF tfidf_lemm_0.05_0.85_4:
# wine,fruit,acidity,ripe,flavor,drink,crisp,rich,fresh,tannin,spice,red,texture,citrus,dry,structure,fruity,year,light,berry,juicy,bright,finish,firm,white,balanced,good,style,peach,soft,make,clean,dark,apple,oak,vineyard,note,touch,fine,balance,aroma,like,spicy,pear,vanilla,mouth,green,cherry,sweet,plum,hint,feel,tannic,offer,chocolate,raspberry,tart,palate,pepper,bit,currant,blackberry,pinot,long,herb,black,nose,black cherry,
# finish,palate,aroma,flavor,note,nose,apple,fruit,berry,wine,peach,green,bit,hint,pear,oak,plum,long,citrus,tart,white,herb,fresh,mouth,vanilla,light,spice,touch,acidity,cherry,drink,feel,offer,good,ripe,bright,sweet,red,like,raspberry,clean,dry,crisp,soft,style,pepper,rich,chocolate,tannin,spicy,make,pinot,dark,blackberry,vineyard,texture,balanced,juicy,balance,tannic,firm,fruity,year,structure,fine,currant,black,black cherry,
# flavor,cherry,sweet,blackberry,tannin,wine,oak,dry,raspberry,good,soft,pinot,spice,currant,rich,chocolate,ripe,finish,vanilla,acidity,drink,year,tannic,fruit,red,fine,like,note,balance,dark,aroma,texture,plum,vineyard,bit,structure,herb,style,mouth,crisp,berry,pepper,offer,feel,tart,balanced,spicy,hint,long,firm,make,fruity,fresh,clean,palate,touch,green,bright,juicy,nose,black,pear,light,peach,white,apple,citrus,black cherry,
# black,black cherry,cherry,tannin,wine,fruit,flavor,plum,finish,palate,currant,pepper,ripe,spice,aroma,dark,chocolate,drink,blackberry,oak,note,red,rich,firm,nose,year,soft,dry,spicy,offer,herb,berry,tannic,vanilla,raspberry,good,juicy,hint,vineyard,acidity,fine,long,balanced,pinot,like,sweet,make,structure,mouth,balance,feel,touch,fruity,texture,bit,fresh,clean,crisp,bright,tart,light,green,white,style,citrus,pear,peach,apple,
#
# TF-IDF tfidf_word_0.2_0.9_4:
# fruit,wine,flavors,finish,aromas,tannins,cherry,acidity,palate,
# finish,palate,aromas,flavors,wine,cherry,acidity,tannins,fruit,
# wine,acidity,flavors,tannins,aromas,cherry,fruit,finish,palate,
# flavors,tannins,cherry,wine,aromas,finish,acidity,palate,fruit,
#
# TF-IDF tfidf_stem_0.2_0.9_4:
# fruit,wine,flavor,acid,finish,cherri,aroma,tannin,palat,
# tannin,wine,cherri,flavor,acid,fruit,finish,aroma,palat,
# palat,aroma,finish,flavor,acid,wine,cherri,fruit,tannin,
# flavor,wine,cherri,acid,finish,aroma,fruit,palat,tannin,
#
# TF-IDF tfidf_lemm_0.2_0.9_4:
# flavor,finish,cherry,aroma,tannin,acidity,wine,fruit,palate,
# wine,flavor,acidity,cherry,tannin,finish,aroma,fruit,palate,
# palate,aroma,finish,flavor,cherry,wine,fruit,tannin,acidity,
# fruit,wine,flavor,finish,acidity,tannin,cherry,aroma,palate,
#
# TF-IDF tfidf_word_0.15_0.9_4:
# palate,finish,aromas,flavors,wine,acidity,oak,ripe,cherry,fruit,tannins,black,
# fruit,wine,flavors,oak,finish,aromas,tannins,cherry,ripe,black,acidity,palate,
# wine,acidity,ripe,flavors,tannins,oak,fruit,black,finish,cherry,aromas,palate,
# flavors,cherry,tannins,black,oak,wine,finish,ripe,aromas,palate,acidity,fruit,
#
# TF-IDF tfidf_stem_0.15_0.9_4:
# note,finish,palat,fruit,flavor,cherri,wine,aroma,tannin,oak,acid,spice,drink,black,ripe,dri,rich,
# flavor,cherri,tannin,dri,black,oak,drink,wine,rich,acid,spice,ripe,finish,fruit,palat,aroma,note,
# aroma,finish,palat,flavor,wine,fruit,acid,oak,spice,cherri,drink,dri,ripe,rich,tannin,black,note,
# wine,fruit,acid,flavor,ripe,rich,drink,spice,tannin,dri,finish,oak,black,cherri,aroma,palat,note,
#
# TF-IDF tfidf_lemm_0.15_0.9_4:
# aroma,palate,flavor,finish,wine,fruit,cherry,acidity,spice,drink,tannin,ripe,black,oak,note,
# wine,fruit,acidity,flavor,ripe,tannin,spice,drink,finish,black,cherry,oak,aroma,palate,note,
# flavor,cherry,oak,tannin,finish,black,wine,spice,drink,acidity,ripe,fruit,palate,aroma,note,
# note,finish,palate,fruit,cherry,flavor,wine,aroma,tannin,oak,spice,drink,acidity,black,ripe,
#
# TF-IDF tfidf_word_0.1_0.9_4:
# ...
# flavor,dri,acid,cherri,spice,finish,wine,tannin,soft,rich,drink,good,berri,red,ripe,balanc,fruit,plum,palat,aroma,note,black,oak,fresh,nose,sweet,blackberri,
# wine,fruit,acid,flavor,ripe,drink,rich,red,balanc,tannin,finish,good,spice,cherri,berri,dri,plum,soft,palat,aroma,fresh,black,blackberri,note,sweet,oak,nose,
# blackberri,flavor,tannin,wine,cherri,dri,oak,soft,black,ripe,finish,rich,drink,good,fruit,spice,aroma,plum,acid,sweet,palat,balanc,note,red,fresh,berri,nose,
# note,finish,fruit,drink,flavor,wine,cherri,acid,aroma,spice,dri,palat,tannin,rich,ripe,plum,berri,red,oak,sweet,balanc,nose,fresh,good,soft,black,blackberri,
# black,cherri,tannin,wine,fruit,flavor,plum,ripe,spice,drink,palat,dri,aroma,finish,rich,red,note,oak,nose,acid,balanc,soft,berri,good,fresh,sweet,blackberri,
# aroma,palat,flavor,finish,berri,fruit,wine,cherri,acid,plum,spice,good,dri,drink,red,rich,tannin,note,ripe,soft,balanc,fresh,oak,sweet,black,blackberri,nose,
# fresh,wine,fruit,acid,flavor,drink,red,aroma,ripe,berri,dri,balanc,spice,finish,palat,tannin,cherri,note,good,rich,soft,plum,sweet,oak,black,nose,blackberri,
# sweet,flavor,wine,acid,soft,fruit,cherri,finish,oak,rich,aroma,ripe,good,drink,spice,tannin,balanc,dri,red,note,palat,berri,plum,black,nose,fresh,blackberri,
# oak,flavor,wine,fruit,finish,ripe,good,acid,rich,cherri,balanc,tannin,note,spice,soft,dri,aroma,red,palat,drink,berri,black,plum,nose,fresh,sweet,blackberri,
#
# TF-IDF tfidf_lemm_0.1_0.95_10:
# soft,flavor,wine,cherry,tannin,sweet,drink,blackberry,finish,fruit,oak,acidity,black,ripe,dry,spice,red,rich,aroma,palate,nose,good,note,plum,fresh,berry,
# flavor,oak,finish,spice,cherry,wine,fruit,blackberry,good,tannin,ripe,rich,acidity,red,berry,plum,drink,palate,aroma,note,black,nose,sweet,soft,dry,fresh,
# wine,fruit,acidity,ripe,flavor,drink,rich,tannin,red,spice,good,finish,cherry,berry,oak,plum,blackberry,palate,dry,aroma,fresh,soft,black,note,nose,sweet,
# black,cherry,tannin,wine,fruit,plum,palate,ripe,aroma,flavor,spice,finish,drink,note,oak,rich,red,blackberry,nose,berry,acidity,good,sweet,dry,soft,fresh,
# aroma,flavor,finish,palate,wine,berry,fruit,cherry,acidity,plum,spice,good,tannin,drink,rich,oak,blackberry,red,ripe,dry,note,sweet,black,fresh,soft,nose,
# fresh,wine,fruit,acidity,flavor,aroma,palate,finish,berry,drink,red,cherry,spice,note,dry,tannin,nose,ripe,good,plum,rich,blackberry,black,oak,sweet,soft,
# sweet,flavor,wine,acidity,cherry,oak,good,fruit,aroma,ripe,rich,finish,spice,drink,tannin,blackberry,plum,note,berry,dry,black,palate,red,nose,fresh,soft,
# dry,flavor,wine,tannin,cherry,acidity,blackberry,finish,good,rich,fruit,drink,spice,black,oak,red,ripe,berry,aroma,plum,note,palate,sweet,fresh,nose,soft,
# note,finish,fruit,wine,flavor,oak,cherry,aroma,palate,drink,spice,acidity,tannin,berry,ripe,red,rich,plum,dry,nose,good,blackberry,sweet,black,fresh,soft,
# nose,palate,finish,flavor,note,aroma,wine,fruit,plum,berry,good,ripe,cherry,tannin,oak,spice,sweet,red,soft,acidity,blackberry,black,drink,fresh,dry,rich,
#
# TF-IDF tfidf_word_0.05_0.95_10:
# sweet,flavors,wine,soft,acidity,oak,cherry,finish,good,ripe,rich,vanilla,aromas,raspberry,like,fruit,crisp,notes,style,pinot,bit,drink,palate,fruity,balanced,tannins,red,spice,plum,spicy,tart,mouth,shows,black,citrus,fruits,chocolate,offers,years,white,nose,touch,dry,peach,green,firm,fine,light,texture,long,tannic,juicy,clean,pepper,fresh,bright,apple,blackberry,cherries,structure,berry,dark,
# black,cherry,tannins,plum,dark,wine,palate,chocolate,flavors,aromas,finish,pepper,fruit,spice,nose,raspberry,soft,ripe,rich,drink,shows,notes,offers,firm,oak,red,vanilla,spicy,tannic,years,juicy,fresh,balanced,long,touch,like,texture,acidity,pinot,good,dry,fine,bit,light,blackberry,fruits,tart,mouth,structure,crisp,bright,style,berry,green,white,clean,sweet,cherries,fruity,citrus,peach,apple,
# fruit,wine,flavors,finish,oak,aromas,red,ripe,spice,cherry,drink,dark,tannins,notes,style,rich,citrus,acidity,chocolate,spicy,like,good,raspberry,bit,years,light,mouth,structure,texture,crisp,tart,vanilla,fresh,palate,balanced,long,nose,shows,juicy,bright,black,soft,plum,firm,fine,green,clean,offers,pinot,touch,peach,dry,pepper,white,tannic,fruity,blackberry,berry,fruits,sweet,apple,cherries,
# wine,acidity,fruits,ripe,fresh,rich,fruity,crisp,flavors,drink,texture,red,structure,light,tannins,juicy,bright,soft,spice,vanilla,white,fruit,citrus,shows,dry,touch,balanced,good,style,clean,fine,years,black,oak,green,peach,finish,dark,raspberry,firm,cherry,plum,spicy,aromas,like,tannic,notes,berry,mouth,palate,pepper,offers,chocolate,sweet,pinot,nose,bit,long,blackberry,tart,apple,cherries,
# dry,flavors,wine,tannins,oak,good,cherry,years,pinot,tannic,soft,acidity,firm,fine,rich,bit,raspberry,like,vanilla,drink,shows,spice,clean,finish,red,structure,tart,fruit,black,ripe,balanced,crisp,style,mouth,long,green,chocolate,texture,offers,aromas,spicy,citrus,fruity,fresh,palate,pepper,white,notes,dark,peach,bright,touch,berry,juicy,fruits,sweet,nose,plum,light,apple,blackberry,cherries,
# finish,palate,notes,aromas,nose,flavors,peach,green,wine,citrus,white,long,tart,acidity,mouth,light,bit,fresh,pinot,shows,clean,drink,bright,touch,vanilla,spice,fruit,ripe,like,oak,good,plum,crisp,rich,soft,dry,raspberry,pepper,offers,cherry,spicy,red,texture,chocolate,juicy,style,fine,tannins,balanced,tannic,firm,sweet,fruity,dark,fruits,years,structure,blackberry,apple,berry,black,cherries,
# apple,flavors,wine,palate,aromas,citrus,green,nose,finish,fruit,acidity,crisp,fresh,light,white,good,peach,drink,oak,notes,offers,clean,sweet,spice,long,ripe,vanilla,texture,mouth,style,bright,soft,tart,like,bit,dry,touch,fruity,balanced,shows,fruits,pinot,rich,red,firm,fine,pepper,years,structure,juicy,spicy,raspberry,berry,tannins,chocolate,cherry,cherries,tannic,blackberry,black,dark,plum,
# berry,aromas,flavors,red,palate,wine,fruit,finish,tannins,cherry,spice,bright,plum,nose,notes,oak,drink,acidity,good,offers,vanilla,tannic,fruits,mouth,dry,firm,pepper,chocolate,dark,fresh,juicy,shows,raspberry,bit,ripe,crisp,sweet,white,spicy,black,style,long,touch,rich,structure,years,fruity,balanced,soft,like,clean,green,light,tart,texture,pinot,blackberry,fine,citrus,cherries,peach,apple,
# blackberry,flavors,tannins,cherry,wine,oak,dry,soft,aromas,finish,shows,black,fruit,plum,ripe,chocolate,good,rich,palate,pepper,drink,spice,sweet,years,tannic,bit,dark,structure,mouth,notes,fine,acidity,texture,spicy,nose,long,vanilla,firm,juicy,bright,crisp,touch,red,like,offers,fresh,fruity,tart,raspberry,green,balanced,style,clean,pinot,white,fruits,berry,citrus,cherries,peach,apple,light,
# cherries,wine,tannins,flavors,black,pinot,dry,oak,sweet,rich,drink,shows,ripe,acidity,fine,red,years,like,palate,fruit,finish,tart,crisp,bit,chocolate,good,structure,notes,pepper,soft,tannic,mouth,texture,dark,aromas,offers,spicy,nose,fruity,light,firm,long,spice,vanilla,clean,fresh,green,touch,juicy,fruits,plum,style,cherry,balanced,white,berry,peach,citrus,blackberry,raspberry,apple,bright,
#
# TF-IDF tfidf_stem_0.05_0.95_10:
# blackberri,flavor,tannin,wine,currant,oak,dri,cherri,soft,chocol,finish,rich,aroma,plum,drink,spice,dark,black,ripe,fruit,fine,pepper,year,sweet,complex,tannic,tast,bit,acid,good,palat,age,balanc,note,mouth,nice,firm,spici,feel,make,vanilla,like,structur,smooth,red,offer,long,herb,fresh,textur,eleg,crisp,vineyard,tart,hint,fruiti,raspberri,juici,bright,toast,nose,touch,style,green,miner,clean,white,pinot,light,berri,black cherri,peach,citrus,appl,pear,
# red,light,fruit,fresh,wine,flavor,crisp,drink,spice,acid,cherri,fruiti,dri,tannin,finish,touch,soft,bright,aroma,currant,palat,raspberri,juici,hint,ripe,textur,plum,white,herb,nice,rich,clean,pepper,style,berri,firm,complex,eleg,oak,vineyard,smooth,offer,tart,green,mouth,balanc,like,miner,nose,chocol,tast,make,structur,spici,dark,note,citrus,tannic,feel,black,fine,vanilla,year,toast,sweet,pear,good,bit,age,pinot,peach,appl,blackberri,black cherri,long,
# flavor,wine,sweet,cherri,finish,aroma,acid,soft,raspberri,vanilla,bit,oak,like,fruit,tannin,dri,spice,tast,plum,tart,chocol,mouth,ripe,offer,textur,rich,nice,palat,drink,dark,make,green,balanc,long,spici,crisp,touch,herb,style,nose,feel,vineyard,note,smooth,firm,complex,clean,tannic,citrus,light,fruiti,peach,pear,eleg,hint,toast,fine,year,fresh,structur,pepper,bright,juici,currant,white,red,miner,black,good,age,blackberri,berri,pinot,black cherri,appl,
# pinot,cherri,raspberri,flavor,acid,wine,drink,oak,spice,sweet,light,dri,fruit,finish,age,vineyard,year,balanc,rich,tart,soft,good,ripe,textur,crisp,nice,offer,mouth,complex,aroma,fine,like,tannin,note,white,hint,black,red,fresh,vanilla,pepper,eleg,structur,herb,feel,peach,make,citrus,pear,tast,currant,spici,style,green,bright,palat,juici,long,tannic,plum,fruiti,blackberri,chocol,nose,smooth,bit,dark,berri,clean,touch,firm,miner,black cherri,toast,appl,
# appl,pear,flavor,green,citrus,aroma,palat,wine,nose,finish,acid,fruit,fresh,crisp,miner,ripe,peach,light,sweet,offer,hint,oak,drink,spice,white,note,vanilla,clean,good,textur,toast,dri,rich,mouth,tart,touch,long,soft,balanc,style,bright,nice,make,like,vineyard,bit,eleg,tast,complex,age,juici,fruiti,firm,herb,structur,feel,fine,year,spici,red,pepper,pinot,smooth,raspberri,currant,berri,tannin,plum,black cherri,black,blackberri,cherri,chocol,tannic,dark,
# note,finish,palat,nose,peach,fruit,aroma,flavor,miner,white,hint,acid,long,citrus,wine,fresh,dri,green,herb,bright,drink,crisp,sweet,touch,clean,pepper,mouth,ripe,textur,spice,eleg,pear,rich,bit,tart,feel,balanc,style,offer,soft,plum,oak,make,toast,cherri,vanilla,raspberri,spici,chocol,light,fruiti,complex,juici,like,fine,nice,dark,vineyard,tast,tannin,red,structur,smooth,tannic,age,firm,year,appl,good,blackberri,pinot,black,berri,black cherri,currant,
# berri,aroma,flavor,wine,fruit,palat,finish,tannin,red,note,spice,cherri,plum,drink,acid,bright,nose,dark,feel,dri,oak,herb,fresh,offer,chocol,firm,juici,pepper,mouth,vanilla,tannic,structur,ripe,toast,balanc,rich,bit,sweet,year,raspberri,spici,black,eleg,hint,white,good,tart,soft,clean,crisp,touch,fruiti,long,smooth,style,like,currant,tast,blackberri,nice,miner,light,green,textur,complex,make,vineyard,fine,citrus,age,pinot,peach,pear,appl,black cherri,
# wine,fruit,age,rich,ripe,acid,flavor,structur,drink,tannin,dri,year,miner,textur,balanc,spice,fresh,oak,fruiti,crisp,fine,dark,style,complex,juici,toast,citrus,make,firm,vineyard,peach,tannic,bright,finish,plum,eleg,smooth,touch,tast,spici,soft,white,black,clean,feel,sweet,cherri,pear,aroma,offer,red,mouth,note,vanilla,like,long,palat,nice,berri,tart,green,currant,chocol,hint,appl,blackberri,good,herb,nose,bit,raspberri,light,pinot,pepper,black cherri,
# black,black cherri,cherri,tannin,wine,fruit,flavor,plum,palat,ripe,currant,aroma,finish,spice,dri,chocol,pepper,drink,note,dark,rich,oak,nose,soft,year,offer,complex,firm,spici,herb,structur,balanc,smooth,red,raspberri,hint,tannic,blackberri,fine,age,long,acid,toast,eleg,vanilla,textur,vineyard,fruiti,nice,like,juici,good,touch,fresh,mouth,feel,make,tast,sweet,bit,light,clean,berri,crisp,tart,pinot,miner,green,bright,white,style,citrus,pear,peach,appl,
# good,flavor,wine,acid,fruit,oak,sweet,finish,ripe,balanc,tannin,cherri,palat,dri,aroma,rich,peach,raspberri,vanilla,nose,like,offer,style,note,bit,clean,citrus,crisp,complex,feel,hint,tart,drink,structur,make,blackberri,year,black,textur,bright,spice,fresh,vineyard,red,toast,appl,soft,nice,berri,spici,touch,smooth,long,fine,herb,age,light,plum,pepper,tast,chocol,tannic,miner,mouth,firm,white,pear,fruiti,currant,eleg,dark,green,juici,pinot,black cherri,
#
# TF-IDF tfidf_lemm_0.05_0.95_10:
# oak,flavor,fruit,wine,blackberry,finish,tannin,good,currant,rich,ripe,note,red,vanilla,aroma,cherry,soft,year,black,palate,dry,peach,balanced,acidity,bit,fine,spice,chocolate,herb,texture,long,offer,drink,like,vineyard,structure,tannic,plum,touch,spicy,style,sweet,crisp,pear,make,balance,firm,nose,mouth,tart,fruity,pepper,feel,apple,fresh,hint,clean,berry,green,raspberry,dark,bright,light,juicy,white,pinot,citrus,black cherry,
# dark,fruit,tannin,chocolate,flavor,wine,plum,finish,aroma,blackberry,note,black,oak,drink,vanilla,spice,cherry,palate,berry,tannic,mouth,structure,texture,raspberry,ripe,pepper,rich,currant,firm,red,nose,dry,offer,acidity,balanced,make,feel,hint,herb,spicy,good,bit,soft,year,like,touch,fine,long,bright,vineyard,fresh,juicy,crisp,style,balance,sweet,white,clean,tart,pinot,fruity,black cherry,pear,citrus,peach,green,apple,light,
# apple,palate,peach,finish,nose,flavor,note,aroma,pear,green,white,acidity,wine,hint,clean,crisp,fresh,fruit,long,offer,ripe,touch,dry,tart,light,drink,mouth,good,pepper,style,bright,herb,soft,spice,make,like,bit,rich,vanilla,texture,vineyard,balanced,sweet,spicy,oak,feel,juicy,fruity,raspberry,red,fine,balance,year,cherry,plum,firm,chocolate,structure,tannin,tannic,pinot,citrus,currant,black,berry,blackberry,dark,black cherry,
# sweet,flavor,wine,soft,acidity,cherry,raspberry,finish,oak,good,like,ripe,aroma,fruit,rich,vanilla,blackberry,tannin,style,spice,bit,drink,crisp,note,fruity,plum,palate,dry,mouth,feel,spicy,pear,peach,vineyard,currant,chocolate,tart,apple,offer,balance,long,white,fine,year,black,touch,texture,red,green,nose,balanced,hint,firm,light,herb,clean,pepper,make,juicy,structure,fresh,tannic,pinot,berry,black cherry,bright,citrus,dark,
# berry,aroma,flavor,palate,wine,red,fruit,finish,tannin,note,spice,cherry,nose,plum,bright,herb,oak,feel,drink,acidity,fresh,pepper,ripe,tannic,offer,vanilla,year,mouth,firm,dry,good,chocolate,juicy,bit,sweet,raspberry,spicy,white,hint,rich,black,balance,tart,crisp,clean,long,style,structure,balanced,fruity,currant,like,soft,dark,touch,make,green,blackberry,light,fine,vineyard,texture,pinot,black cherry,citrus,pear,apple,peach,
# flavor,cherry,finish,blackberry,tannin,wine,dry,aroma,raspberry,fruit,plum,spice,chocolate,good,bit,note,soft,vanilla,like,palate,tannic,rich,herb,drink,long,year,feel,tart,red,mouth,ripe,nose,currant,hint,firm,acidity,spicy,fresh,structure,texture,make,touch,balance,style,fine,bright,pepper,crisp,green,light,vineyard,clean,juicy,balanced,fruity,offer,black,white,oak,pear,dark,sweet,pinot,berry,peach,citrus,apple,black cherry,
# black,black cherry,cherry,tannin,wine,flavor,ripe,plum,fruit,palate,spice,aroma,finish,pepper,drink,currant,note,rich,nose,blackberry,soft,firm,chocolate,year,herb,red,offer,spicy,raspberry,dry,oak,dark,fine,long,juicy,hint,good,vineyard,acidity,vanilla,structure,like,tannic,feel,balance,bit,make,balanced,fruity,clean,berry,fresh,mouth,pinot,crisp,sweet,texture,touch,light,green,tart,bright,white,style,citrus,pear,peach,apple,
# citrus,flavor,fruit,wine,apple,finish,aroma,palate,acidity,crisp,note,peach,green,nose,dry,good,pear,drink,fresh,bright,rich,bit,vanilla,like,texture,white,ripe,oak,spice,mouth,clean,touch,balance,hint,sweet,feel,long,year,make,tart,structure,fine,light,balanced,spicy,soft,vineyard,pinot,firm,pepper,style,juicy,offer,red,berry,fruity,raspberry,currant,herb,plum,tannic,black,chocolate,black cherry,blackberry,tannin,dark,cherry,
# wine,fruit,acidity,ripe,rich,red,drink,fresh,flavor,spice,light,fruity,tannin,crisp,texture,juicy,finish,dry,bright,structure,soft,year,vineyard,style,balanced,touch,fine,good,balance,note,clean,firm,make,hint,palate,tannic,currant,plum,mouth,aroma,white,green,spicy,black,cherry,raspberry,vanilla,berry,apple,blackberry,feel,nose,pear,like,offer,tart,chocolate,bit,peach,pepper,herb,long,sweet,oak,citrus,black cherry,dark,pinot,
# pinot,cherry,raspberry,flavor,wine,drink,oak,dry,acidity,spice,fruit,tart,light,vineyard,finish,year,hint,balance,good,soft,sweet,crisp,texture,ripe,tannin,red,mouth,aroma,herb,note,pear,fine,offer,pepper,like,fresh,green,white,black,structure,vanilla,feel,currant,make,spicy,blackberry,palate,juicy,rich,style,nose,tannic,plum,berry,apple,balanced,bit,fruity,peach,touch,clean,chocolate,long,bright,firm,dark,citrus,black cherry,

# %% [markdown]
# ## Multidimensional scaling
#
# # NOTE: also try PCA here.

# %%
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1, n_jobs=-1)

pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

xs, ys = pos[:, 0], pos[:, 1]

# %% [markdown]
# ## Visualizing review clusters

# %%
# #set up colors per clusters using a dict
# cluster_colors = {0: '#1b9e77', 1: '#d95f02', 2: '#7570b3', 3: '#e7298a', 4: '#66a61e'}

# #set up cluster names using a dict
# cluster_names = {0: '0', 
#                  1: '1', 
#                  2: '2'}

# %%
# df = pd.DataFrame(dict(x=xs, y=ys, label=clusters)) 

# #group by cluster
# groups = df.groupby('label')


# # set up plot
# fig, ax = plt.subplots(figsize=(17, 9)) # set size
# ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling

# #iterate through groups to layer the plot
# #note that I use the cluster_name and cluster_color dicts with the 'name' lookup to return the appropriate color/label
# for name, group in groups:
#     ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, 
#             label=cluster_names[name], color=cluster_colors[name], 
#             mec='none')
#     ax.set_aspect('auto')
#     ax.tick_params(\
#         axis= 'x',          # changes apply to the x-axis
#         which='both',      # both major and minor ticks are affected
#         bottom='off',      # ticks along the bottom edge are off
#         top='off',         # ticks along the top edge are off
#         labelbottom='off')
#     ax.tick_params(\
#         axis= 'y',         # changes apply to the y-axis
#         which='both',      # both major and minor ticks are affected
#         left='off',      # ticks along the bottom edge are off
#         top='off',         # ticks along the top edge are off
#         labelleft='off')
    
# ax.legend(numpoints=1)  #show legend with only 1 point

# #add label in x,y position with the label as the film title
# for i in range(len(df)):
#     ax.text(df.ix[i]['x'], df.ix[i]['y'], df.ix[i]['title'], size=8)

# %%
# from scipy.cluster.hierarchy import ward, dendrogram

# linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances

# fig, ax = plt.subplots(figsize=(15, 20)) # set size
# ax = dendrogram(linkage_matrix, orientation="right")

# %% [markdown]
# ## Gensim

# %%
texts = data.word_stem.tolist()
dictionary = corpora.Dictionary(texts)

# %%
dictionary.filter_extremes(no_below=1, no_above=0.8)

#convert the dictionary to a bag of words corpus for reference
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
models.LdaModel?

# %%
totalvocab_stemmed = [['a', 'b', 'cow'],['ernie','is','my','cat']]

# %%
[[' '.join(x)] for x in totalvocab_stemmed]
# Out:
# [['a b cow'], ['ernie is my cat']]

# %%
[' '.join(x) for x in totalvocab_stemmed]
# Out:
# ['a b cow', 'ernie is my cat']

# %%
# %time lda = models.LdaModel(corpus, num_topics=5, id2word=dictionary, update_every=5, chunksize=10000, passes=100)
# Out:
# CPU times: user 11min 19s, sys: 1.61 s, total: 11min 20s
# Wall time: 11min 16s

# %%
! echo "pushover 'scrape finished'" | /bin/zsh

# %%
lda.show_topics()
# Out:
# [(0,
#   '0.027*flavor + 0.025*wine + 0.019*acid + 0.017*fruit + 0.015*finish + 0.014*appl + 0.011*palat + 0.011*note + 0.010*crisp + 0.010*citrus'),
#  (1,
#   '0.025*flavor + 0.020*finish + 0.012*aroma + 0.011*fruit + 0.009*palat + 0.009*like + 0.008*feel + 0.007*littl + 0.006*oak + 0.005*chardonnay'),
#  (2,
#   '0.027*flavor + 0.024*wine + 0.016*fruit + 0.015*black + 0.015*tannin + 0.014*aroma + 0.013*finish + 0.011*cherri + 0.011*blackberri + 0.010*oak'),
#  (3,
#   '0.033*wine + 0.028*fruit + 0.014*flavor + 0.014*tannin + 0.012*cherri + 0.012*spice + 0.011*aroma + 0.009*acid + 0.009*drink + 0.009*red'),
#  (4,
#   '0.029*cherri + 0.021*flavor + 0.014*finish + 0.014*pinot + 0.011*drink + 0.010*wine + 0.009*soft + 0.009*noir + 0.008*spice + 0.008*cola')]

# %%
import dill

# %%
with open('lda','wb') as fh:
    dill.dump(lda, fh)
    
with open('corpus','wb') as fh:
    dill.dump(corpus, fh)
    
with open('dictionary','wb') as fh:
    dill.dump(dictionary, fh)

# %%
import funcy as fp
# import pyLDAvis.gensim
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-232-004136ed67dc> in <module>()
# ----> 1 import funcy as fp
#       2 # import pyLDAvis.gensim
#
# ImportError: No module named 'funcy'

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-50e2c9d9c6fd> in <module>()
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
# !which python
# Out:
# /home/ubuntu/miniconda/envs/scienv3/bin/python
